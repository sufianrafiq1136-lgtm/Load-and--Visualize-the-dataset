# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import yfinance as yf

# %%
stock1 = yf.Ticker("AAPL")
stock2=yf.Ticker("GOOG")

# %%
df=stock1.history(period="1y")

# %%
X=df[['Open','High','Low','Volume']]
Y=df['Close']

# %%
print(stock1.history(period="1y"))
# Out:
#                                  Open        High         Low       Close  \
# Date
# 2024-07-19 00:00:00-04:00  223.773490  225.744269  222.240650  223.265854
# 2024-07-22 00:00:00-04:00  225.953286  226.719706  222.051535  222.917496
# 2024-07-23 00:00:00-04:00  223.325565  225.883609  221.643430  223.962585
# 2024-07-24 00:00:00-04:00  222.957296  223.753575  216.119280  217.522705
# 2024-07-25 00:00:00-04:00  217.910884  219.821960  213.620949  216.477600
# ...                               ...         ...         ...         ...
# 2025-07-14 00:00:00-04:00  209.929993  210.910004  207.539993  208.619995
# 2025-07-15 00:00:00-04:00  209.220001  211.889999  208.919998  209.110001
# 2025-07-16 00:00:00-04:00  210.300003  212.399994  208.639999  210.160004
# 2025-07-17 00:00:00-04:00  210.570007  211.800003  209.589996  210.020004
# 2025-07-18 00:00:00-04:00  210.869995  211.789993  209.699997  211.179993
#
#                              Volume  Dividends  Stock Splits
# Date
# 2024-07-19 00:00:00-04:00  49151500        0.0           0.0
# 2024-07-22 00:00:00-04:00  48201800        0.0           0.0
# 2024-07-23 00:00:00-04:00  39960300        0.0           0.0
# 2024-07-24 00:00:00-04:00  61777600        0.0           0.0
# 2024-07-25 00:00:00-04:00  51391200        0.0           0.0
# ...                             ...        ...           ...
# 2025-07-14 00:00:00-04:00  38840100        0.0           0.0
# 2025-07-15 00:00:00-04:00  42296300        0.0           0.0
# 2025-07-16 00:00:00-04:00  47490500        0.0           0.0
# 2025-07-17 00:00:00-04:00  48068100        0.0           0.0
# 2025-07-18 00:00:00-04:00  48939500        0.0           0.0
#
# [250 rows x 7 columns]

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, shuffle=False)

# %%
# Option 1: Linear Regression
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
predictions = model.predict(X_test)

# %%
print(predictions)
# Out:
# [194.44583096 197.07088746 199.07199668 207.88723177 211.78933733
#  212.3059361  211.61393539 210.55816168 206.46571101 206.42430923
#  203.21538054 201.6987327  196.5935234  199.63191422 201.92198356
#  199.89998278 199.34615637 201.88420178 203.13154492 205.12544394
#  201.94795738 204.56887296 202.16658732 203.6585351  200.33595188
#  198.3800509  197.192451   198.01064958 196.81542621 196.72166531
#  199.61578836 200.13307767 201.47255707 202.79220884 200.96193695
#  201.36910007 203.91528468 208.92206895 211.81207032 214.13753005
#  212.61556008 210.04865243 209.28917809 212.67945893 211.4651981
#  209.05779046 211.30813867 210.81910159 210.90978105 210.80295621]

# %%
import matplotlib.pyplot as plt

# Make sure y_test is in a NumPy array format if needed
import numpy as np
y_test_values = np.array(y_test)

# Plot
plt.figure(figsize=(12, 6))
plt.plot(y_test_values, label='Actual Close Price', color='blue')
plt.plot(predictions, label='Predicted Close Price', color='red')vvv')
plt.xlabel('Days')
plt.ylabel('Price')
plt.legend()
plt.grid(True)
plt.show()
